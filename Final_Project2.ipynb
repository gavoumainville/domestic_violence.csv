# %% [markdown]
# <a href="https://colab.research.google.com/github/gavoumainville/domestic_violence.csv/blob/main/Final_Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/gavoumainville/domestic_violence.csv/main/ENDGBV_NYCfinal.csv")

df
# Out:
#         Offense Type Report Date  Incident Precinct Code Borough Name  \
# 0                DIR  12/31/2021                      40        BRONX
# 1                DIR  12/31/2021                      40        BRONX
# 2                DIR  12/31/2021                      40        BRONX
# 3                DIR  12/31/2021                      40        BRONX
# 4                DIR  12/31/2021                      40        BRONX
# ...              ...         ...                     ...          ...
# 1012             DIR  12/30/2021                      77     BROOKLYN
# 1013             DIR  12/30/2021                      71     BROOKLYN
# 1014             DIR  12/30/2021                      71     BROOKLYN
# 1015  FELONY ASSAULT  12/30/2021                      71     BROOKLYN
# 1016             DIR  12/30/2021                      71     BROOKLYN
#
#      Intimate Relationship Flag Victim Race Victim Sex  Victim Reported Age  \
# ...
